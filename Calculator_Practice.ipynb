# %% [markdown]
# <a href="https://colab.research.google.com/github/Asad4480/Calculator_Practice/blob/main/Calculator_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
from IPython.display import display
import math

# Define functions for the calculator
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Division by zero"
    return a / b

def sin(x):
    return math.sin(math.radians(x))

def cos(x):
    return math.cos(math.radians(x))

def tan(x):
    return math.tan(math.radians(x))

def log(x):
    return math.log10(x)

def sqrt(x):
    return math.sqrt(x)

# Correct clear_fields function
def clear_fields(b):
    num1.value = 0.0  # Reset the value to 0.0 (valid float)
    num2.value = 0.0  # Reset the value to 0.0 (valid float)
    result.value = ''  # Reset the result field (Text widget) to an empty string

# Define the layout of the calculator
num1 = widgets.FloatText(placeholder="Enter first number", description="Num 1:", value=0.0)
num2 = widgets.FloatText(placeholder="Enter second number (if needed)", description="Num 2:", value=0.0)

result = widgets.Text(value='', description="Result:")

# Buttons for operations
buttons = widgets.HBox([
    widgets.Button(description="Add", button_style='success'),
    widgets.Button(description="Subtract", button_style='info'),
    widgets.Button(description="Multiply", button_style='warning'),
    widgets.Button(description="Divide", button_style='danger'),
])

# Scientific functions
scientific_buttons = widgets.HBox([
    widgets.Button(description="Sin", button_style='primary'),
    widgets.Button(description="Cos", button_style='primary'),
    widgets.Button(description="Tan", button_style='primary'),
    widgets.Button(description="Log", button_style='primary'),
    widgets.Button(description="Sqrt", button_style='primary'),
])

# Clear button
clear_button = widgets.Button(description="Clear", button_style='danger')

# Display the elements
display(num1, num2, buttons, scientific_buttons, result, clear_button)

# Define button event handlers
def on_add_clicked(b):
    result.value = str(add(num1.value, num2.value))

def on_subtract_clicked(b):
    result.value = str(subtract(num1.value, num2.value))

def on_multiply_clicked(b):
    result.value = str(multiply(num1.value, num2.value))

def on_divide_clicked(b):
    result.value = str(divide(num1.value, num2.value))

def on_sin_clicked(b):
    result.value = str(sin(num1.value))

def on_cos_clicked(b):
    result.value = str(cos(num1.value))

def on_tan_clicked(b):
    result.value = str(tan(num1.value))

def on_log_clicked(b):
    if num1.value > 0:
        result.value = str(log(num1.value))
    else:
        result.value = "Error: Logarithm of non-positive number"

def on_sqrt_clicked(b):
    if num1.value >= 0:
        result.value = str(sqrt(num1.value))
    else:
        result.value = "Error: Square root of negative number"

# Assign button clicks to their respective functions
buttons.children[0].on_click(on_add_clicked)
buttons.children[1].on_click(on_subtract_clicked)
buttons.children[2].on_click(on_multiply_clicked)
buttons.children[3].on_click(on_divide_clicked)

scientific_buttons.children[0].on_click(on_sin_clicked)
scientific_buttons.children[1].on_click(on_cos_clicked)
scientific_buttons.children[2].on_click(on_tan_clicked)
scientific_buttons.children[3].on_click(on_log_clicked)
scientific_buttons.children[4].on_click(on_sqrt_clicked)

clear_button.on_click(clear_fields)
# Out:
# FloatText(value=0.0, description='Num 1:')
# FloatText(value=0.0, description='Num 2:')
# ...
# Text(value='', description='Result:')
# Button(button_style='danger', description='Clear', style=ButtonStyle())

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 85.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 118.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.8 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import math

# Define functions for the calculator
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Division by zero"
    return a / b

def sin(x):
    return math.sin(math.radians(x))

def cos(x):
    return math.cos(math.radians(x))

def tan(x):
    return math.tan(math.radians(x))

def log(x):
    return math.log10(x)

def sqrt(x):
    return math.sqrt(x)

# Create the Streamlit app interface
st.title("Scientific Calculator")

# Get user input
num1 = st.number_input("Enter first number", value=0.0)
num2 = st.number_input("Enter second number (if needed)", value=0.0)

# Operation buttons
operation = st.selectbox("Choose an operation", ["Add", "Subtract", "Multiply", "Divide", "Sin", "Cos", "Tan", "Log", "Sqrt"])

# Result output
if st.button("Calculate"):
    if operation == "Add":
        result = add(num1, num2)
    elif operation == "Subtract":
        result = subtract(num1, num2)
    elif operation == "Multiply":
        result = multiply(num1, num2)
    elif operation == "Divide":
        result = divide(num1, num2)
    elif operation == "Sin":
        result = sin(num1)
    elif operation == "Cos":
        result = cos(num1)
    elif operation == "Tan":
        result = tan(num1)
    elif operation == "Log":
        if num1 > 0:
            result = log(num1)
        else:
            result = "Error: Logarithm of non-positive number"
    elif operation == "Sqrt":
        if num1 >= 0:
            result = sqrt(num1)
        else:
            result = "Error: Square root of negative number"

    st.success(f"Result: {result}")

# Clear button (reset values)
if st.button("Clear"):
    st.experimental_rerun()
# Out:
# 2024-10-16 14:35:18.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-16 14:35:18.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
